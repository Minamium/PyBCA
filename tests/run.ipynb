# %%
# !ls
# !nvidia-smi
# Out:
# PyBCA  jupyter_8890.log  run_jupyter.sh  venv
# Thu Dec 18 16:19:21 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.274.02             Driver Version: 535.274.02   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3070 ...    Off | 00000000:01:00.0 Off |                  N/A |
# | N/A   56C    P8              17W /  90W |      8MiB /  8192MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      5757      G   /usr/lib/xorg/Xorg                            4MiB |
# +---------------------------------------------------------------------------------------+

# %%
# !rm -rf PyBCA
# !git clone https://github.com/Minamium/PyBCA.git
# !pip install -e ./PyBCA
# Out:
# Cloning into 'PyBCA'...
# remote: Enumerating objects: 893, done.
# remote: Counting objects: 100% (259/259), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 893 (delta 141), reused 194 (delta 83), pack-reused 634 (from 1)
# Receiving objects: 100% (893/893), 1.22 MiB | 7.37 MiB/s, done.
# Resolving deltas: 100% (486/486), done.
# Obtaining file:///home/arlm/bcaTest/PyBCA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in ./venv/lib/python3.12/site-packages (from PyBCA==0.3.0) (2.3.2)
# Requirement already satisfied: torch>=2.0 in ./venv/lib/python3.12/site-packages (from PyBCA==0.3.0) (2.8.0)
# Requirement already satisfied: scipy in ./venv/lib/python3.12/site-packages (from PyBCA==0.3.0) (1.16.1)
# Requirement already satisfied: pyyaml in ./venv/lib/python3.12/site-packages (from PyBCA==0.3.0) (6.0.2)
# Requirement already satisfied: filelock in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (4.14.1)
# Requirement already satisfied: setuptools in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (1.14.0)
# Requirement already satisfied: networkx in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (3.5)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (3.1.6)
# Requirement already satisfied: fsspec in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (2025.7.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in ./venv/lib/python3.12/site-packages (from torch>=2.0->PyBCA==0.3.0) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.0->PyBCA==0.3.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.12/site-packages (from jinja2->torch>=2.0->PyBCA==0.3.0) (3.0.2)
# Building wheels for collected packages: PyBCA
#   Building editable for PyBCA (pyproject.toml) ... done
#   Created wheel for PyBCA: filename=pybca-0.3.0-0.editable-py3-none-any.whl size=2631 sha256=48532c751335f9a82b177b7db0617e1b6f45fa413cc8e85676b7592e43d60a0a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8myy114z/wheels/29/94/52/3c8e7e7a0440d2c10e64b2302ee66f5d580f642223ac45d058
# Successfully built PyBCA
# Installing collected packages: PyBCA
#   Attempting uninstall: PyBCA
#     Found existing installation: PyBCA 0.3.0
#     Uninstalling PyBCA-0.3.0:
#       Successfully uninstalled PyBCA-0.3.0
# Successfully installed PyBCA-0.3.0

# %%
from PyBCA.cli_simClass import BCA_Simulator
from PyBCA import lib, load_state_conversions_from_yaml

cellspace_path = "PyBCA/Sample/Cellspace/BNN.yaml"
rule_paths = [
        "PyBCA/Sample/rule/base-rule.yaml",
        "PyBCA/Sample/rule/Join_fork.yaml"
        ]
    
simulator = BCA_Simulator(cellspace_path, rule_paths, device="cuda",
                              spatial_event_filePath="PyBCA/Sample/Specialevent/BNN_event.py",
                              use_tqdm=True,
                              trial_constant_sweep = {
                                  "join_err_0_input": {"base": 0.0,    "delta": 0.000001},
                                  "join_err_1_input": {"base": 0.0,    "delta": 0.00001},
                                  "fork_err_0_input": {"base": 0.0,    "delta": 0.000001},
                                 })
                        
simulator.Allocate_torch_Tensors_on_Device()

# %%
simulator.set_ParallelTrial(500)

simulator.run_steps(steps=80_000, 
                    global_prob=0.5, 
                    seed=1, 
                    debug=False, 
                    debug_per_trial=False, 
                    state_gate_enable=True, 
                    state_gate_interval=300)
