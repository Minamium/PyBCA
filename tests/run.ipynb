# %%
# !ls
# !nvidia-smi
# Out:
# PyBCA  jupyter_8890.log  run_jupyter.sh  venv
# Thu Dec 18 15:04:47 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.274.02             Driver Version: 535.274.02   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3070 ...    Off | 00000000:01:00.0 Off |                  N/A |
# | N/A   39C    P0              N/A /  90W |      8MiB /  8192MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !git clone https://github.com/Minamium/PyBCA.git
# !pip install -e ./PyBCA
# Out:
# Cloning into 'PyBCA'...
# remote: Enumerating objects: 879, done.
# remote: Counting objects: 100% (245/245), done.
# remote: Compressing objects: 100% (163/163), done.
# remote: Total 879 (delta 135), reused 183 (delta 80), pack-reused 634 (from 1)
# Receiving objects: 100% (879/879), 1.14 MiB | 6.36 MiB/s, done.
# Resolving deltas: 100% (480/480), done.
# Obtaining file:///home/arlm/bcaTest/PyBCA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for PyBCA (pyproject.toml) ... done
#   Created wheel for PyBCA: filename=pybca-0.3.0-0.editable-py3-none-any.whl size=2631 sha256=8e80a456141693d1a832a33f3b1729becc17e2826aaf7cd452d989ea91d8f4bc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pc_5lm1d/wheels/29/94/52/3c8e7e7a0440d2c10e64b2302ee66f5d580f642223ac45d058
# Successfully built PyBCA
# ...
